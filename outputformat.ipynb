# %%
#outputformat
a=input("enter the format 3: ")
b=input("enter the type of output format as type1 or type 2: ")
def outputformat(a,b):
    if(b=="type1"):
        n=[]
        r=[]
        c=a.split(" ")
        for i in c:
            d=int(i)
            e=format(d, "b")
            f=str(e)
            g=""
            for h in f:
                j=int(h)
                k=j+1
                l=str(k)
                g+=l
            n.append(g)
        aa=" ".join(n)
        bb=list(aa)
        cc=reversed(bb)
        dd="".join(cc)
        ee=d.split(" ")
        for o in ee:
            p=int(o)
            q=format(p, "o")
            s=str(q)
            r.append(s)
        t=" ".join(r)
        return t
    else:
        n=[]
        r=[]
        c=a.split(" ")
        for i in c:
            d=int(i)
            e=format(d, "o")
            f=str(e)
            g=""
            for h in f:
                j=int(h)
                k=j+1
                l=str(k)
                g+=l
            n.append(g)
        aa=" ".join(n)
        bb=list(aa)
        cc=reversed(bb)
        dd="".join(cc)
        ee=d.split(" ")
        for o in ee:
            p=int(o)
            q=format(p, "b")
            s=str(q)
            r.append(s)
        t=" ".join(r)
        return t
outputformat(a,b)
